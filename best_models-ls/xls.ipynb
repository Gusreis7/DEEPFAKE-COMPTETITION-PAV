# %%
import pandas as pd

# %%
df_xls = pd.read_csv("test_teste-by-best_model-w2v-xls_new.csv")
df_xls.hist()
# Out:
# array([[<Axes: title={'center': 'fake_prob'}>]], dtype=object)

# %%
df_xls_aug = pd.read_csv("test_teste-by-best_model-w2v-xls-new_aug.csv")
df_xls_aug.hist(bins=20,figsize=(14,6))
# Out:
# array([[<Axes: title={'center': 'fake_prob'}>]], dtype=object)
